# %% [markdown]
# ## Initialization

# %%
import sys

sys.path.append('../lib/nameh-khan')

# %% [markdown]
# ## Import

# %%
import cv2
import matplotlib.pyplot as plt

from nameh_khan.page_reader.plain_text_page import PlainTextPageReader

# %% [markdown]
# ## Loading Image

# %%
image = cv2.imread('../training/raw-data/Arshasb_7k/06500/page_06500.png')
plt.imshow(image)
plt.show()

# %% [markdown]
# ## Instantiating Model

# %%
page_reader = PlainTextPageReader()
output_text = page_reader.transform(image)
print(output_text)
# Out:
#  6500
# کشور از گذرگاه مرزی ابو سمره میان قطر و عربستان را دارند باید از
# امروز، اقدامات پیشگیرانه‌ای را انجام دهند.
# وی گفت که همه افراد باید 72 ساعت پیش از سفر به قطر آزمایش ویروس
# کرونا داده و مدرک عدم ابتلا به کرونا را همراه داشته باشند و دریک هتل
# مشخص شده توسط دولت قطر به مدت یک هفته قرنطینه شوند.
# در همین حال، شبکه الأخباریه از ورود نخستین قطری به عربستان از
# طریق گذرگاه مرزی سلوی خبرداد.
# طبق گزارش این شبکه، امروز گذرگاه مرزی سلوی میان عربستان و
# قطر به شکل رسمی فعالیتش را از سر گرفت و نخستین قطری پس از آشتی
# میان دو کشور وارد بخش مربوط به عربستان در این گذرگاه شدند.
# با ورود خودروی این فرد به بخش مربوط به عربستان در گذرگاه سلوی،
# پرسنل عربستان به بررسی و احراز هویت اسناد شناسایی راننده وسیله
# نقلیه آن کردند.
# طبق این گزارش، نخستین قطری که وارد خاک عربستان شد در این باره
# گفت: ما به کشور دوممان می‌شویم و خوشحال هستیم
# وی همچنین تدابیر اتخاذ شده در گذرگاه را ستود و افزود: همه
# همکاری کرده و با گل از او استقبال کردند و یک پیام برای شهروندان
# قطری دارم که تمایل به سفر به عربستان دارند و آن این استکه تدابیرو
# اقدامات اتخاذ شده ساده بوده و برادرانمان در عربستان به دلیل ورود ما
